# %%
pip install textblob
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# ...

# %%
    text = "We'll go over an example of how to design and implement an LLM-powered chatbot. This chatbot will be able to have a conversation and remember previous interactions with a chat model."
from textblob import TextBlob
word_blob = TextBlob(text)
print("Words break down:", word_blob.words)
print("Sentence break down:", word_blob.sentences)
# Out:
# Words break down: ['We', "'ll", 'go', 'over', 'an', 'example', 'of', 'how', 'to', 'design', 'and', 'implement', 'an', 'LLM-powered', 'chatbot', 'This', 'chatbot', 'will', 'be', 'able', 'to', 'have', 'a', 'conversation', 'and', 'remember', 'previous', 'interactions', 'with', 'a', 'chat', 'model']
# Sentence break down: [Sentence("We'll go over an example of how to design and implement an LLM-powered chatbot."), Sentence("This chatbot will be able to have a conversation and remember previous interactions with a chat model.")]

# %%
#chunk  - sentence break down with meaningful information 
#tokenization - splitting into words

print("POS tagging breakdown:", word_blob.tags)
# Out:
# POS tagging breakdown: [('We', 'PRP'), ("'ll", 'MD'), ('go', 'VB'), ('over', 'IN'), ('an', 'DT'), ('example', 'NN'), ('of', 'IN'), ('how', 'WRB'), ('to', 'TO'), ('design', 'VB'), ('and', 'CC'), ('implement', 'VB'), ('an', 'DT'), ('LLM-powered', 'JJ'), ('chatbot', 'NN'), ('This', 'DT'), ('chatbot', 'NN'), ('will', 'MD'), ('be', 'VB'), ('able', 'JJ'), ('to', 'TO'), ('have', 'VB'), ('a', 'DT'), ('conversation', 'NN'), ('and', 'CC'), ('remember', 'VB'), ('previous', 'JJ'), ('interactions', 'NNS'), ('with', 'IN'), ('a', 'DT'), ('chat', 'NN'), ('model', 'NN')]

# %%
print("sentiment analysis:", word_blob.sentiment)
# Out:
# sentiment analysis: Sentiment(polarity=0.16666666666666669, subjectivity=0.3958333333333333)

# %%
print("upper case:", word_blob.upper())
# Out:
# upper case: WE'LL GO OVER AN EXAMPLE OF HOW TO DESIGN AND IMPLEMENT AN LLM-POWERED CHATBOT. THIS CHATBOT WILL BE ABLE TO HAVE A CONVERSATION AND REMEMBER PREVIOUS INTERACTIONS WITH A CHAT MODEL.

# %%
print("lower case:", word_blob.lower())
# Out:
# lower case: we'll go over an example of how to design and implement an llm-powered chatbot. this chatbot will be able to have a conversation and remember previous interactions with a chat model.

# %%
text = "We'll go over an example of how to design and implement an LLM-powered chatbotee. This chatbot will be able to have a conversition and remember prevous interactions with a chat model."

# %%
word_blob1 = TextBlob(text)
print("spelling correction:", word_blob1.correct())
# Out:
# spelling correction: He'll go over an example of how to design and implement an LLM-lowered chatbotee. His charcot will be able to have a conversation and remember previous interactions with a chat model.

# %%
pip install googletrans
# Out:
# ...
#   Obtaining dependency information for googletrans from https://files.pythonhosted.org/packages/3c/9c/3ec8e2a1f9bf57b8ee3a26c49d0dcbfa21d54d412d2e7d158fac46fa6e67/googletrans-4.0.2-py3-none-any.whl.metadata
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
from googletrans import LANGUAGES, Translator
language_code = dict(map(reversed, LANGUAGES.items()))
language_code
# Out:
# {'abkhaz': 'abk',
#  'acehnese': 'ace',
#  'acholi': 'ach',
#  'afar': 'aar',
#  'afrikaans': 'af',
#  'albanian': 'sq',
#  'alur': 'alz',
#  'amharic': 'am',
#  'arabic': 'ar',
#  'armenian': 'hy',
#  'assamese': 'as',
#  'avar': 'ava',
#  'awadhi': 'awa',
#  'aymara': 'ay',
#  'azerbaijani': 'az',
#  'balinese': 'ban',
#  'baluchi': 'bal',
#  'bambara': 'bm',
#  'baoulé': 'bci',
#  'bashkir': 'bak',
#  'basque': 'eu',
#  'batak karo': 'btx',
#  'batak simalungun': 'bts',
#  'batak toba': 'bbc',
#  'belarusian': 'be',
#  'bemba': 'bem',
#  'bengali': 'bn',
#  'betawi': 'bew',
#  'bhojpuri': 'bho',
#  'bikol': 'bik',
#  'bosnian': 'bs',
#  'breton': 'bre',
#  'bulgarian': 'bg',
#  'buryat': 'bua',
#  'cantonese': 'yue',
#  'catalan': 'ca',
#  'cebuano': 'ceb',
#  'chamorro': 'cha',
#  'chechen': 'che',
#  'chinese': 'zh',
#  'chinese (simplified)': 'zh-cn',
#  'chinese (traditional)': 'zh-tw',
#  'chuukese': 'chk',
#  'chuvash': 'chv',
#  'corsican': 'co',
#  'crimean tatar': 'crh',
# ...

# %% [raw]
# #(NLTK - textblob -- spacy -- google trans )  AI  40 % success -- Transformer(2017) 60 %  -- BERT(2019) -- BART(2021) / Chatgpt2(2021) --

# %%
translator = Translator()
print("translating the sentence:",translator

# %%
# work -- working, worked  -- work, working, worked   - binary representation  -- activity, task 
#  Relationship and equvalent word with closes meaning 
# Vectorization is a method created to understand the closed meaning information word with the root word 
# i am working
# i am doing some activity  - i am activity doing some 
# i am doing a task 

# vectorization technic 

# text generation - i am able for other person 

#                            1. split the work and tokenization
#                         2 . vectorization has word embeding 
#                         3. position encoding 

# i am walking( 90 %) / working( 90%) /(sleeping 90 %) /running (90%)
# i am walking inside my home( 40 %) / down( 40 % / on the road ( 90 %)

#                                           i am walking on the road ( priority)  -- 10 % 
#                                           i am sleeping on my bed  - ( CBOW) similarity format
