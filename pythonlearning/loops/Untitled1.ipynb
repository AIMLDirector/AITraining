# %%
pip list
# Out:
# Package                                  Version
# ---------------------------------------- --------------
# absl-py                                  2.3.1
# accelerate                               1.10.0
# aiocache                                 0.12.3
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.11.11
# aiosignal                                1.4.0
# alembic                                  1.14.0
# annotated-types                          0.7.0
# anthropic                                0.62.0
# anyio                                    4.10.0
# appdirs                                  1.4.4
# appnope                                  0.1.4
# APScheduler                              3.10.4
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     25.1.0
# arrow                                    1.3.0
# ...

# %%
ð
